# %% [markdown]
# # DICTIONARY
# - A lot from ChatGPT but unknown how to cite that so not cited at this time.
#
# - Updated throughout my learning jounrey as I come across terms I am confusing with each other often and have to ask ChatGPT to help determine between them
#
# - Doing my best to arrange them alphabetically

# %% [markdown]
# ## **Command**
# -------------------------------------------------------------------
#
# #### **<u> Definition </u>**:
# = Refers to an instruction given to a computer program to perform a specific action. Its a more general term and can encompass <font color="blue"> **functions** </font>, <font color="RoyalBlue"> **methods** </font>, or even direct instructions in a **command-line interface**
#
# >
# >
#
# #### **<u> Markdown Color </u>**:
# - "blue"
# - <font color="blue"> **command** </font>
#
# >
# >
#
# ------------------------------------------------------------

# %% [markdown]
# ## **Function**
#
# ------------------------------------------------------------
#
# #### **<u> Definition </u>**:
# = A <font color="SteelBlue"> **block of code** </font> that performs a specific task and can be reused in a <font color="BlueViolet"> **program** </font>
#
# >
# >
#
# #### **<u> Action </u>**:
# - It takes inputs (= <font color="red"> **arguments** </font>) -> performs some **operations** -> may **return an output**
#
# >
# >
#
# #### **<u> Markdown Color </u>**:
# - "blue"
# - <font color="blue"> **function** </font>
#
# >
# >
# #### **<u> Examples </u>**:
#
# - List of examples of **Built-in Python** <font color="blue"> **functions** </font>
# - RETURNS = prints to the console
# >
# >
#
# |     |     |     |
# | --- | --- | --- |
# | '<font color="blue"> **print()** </font>' |  | Takes input and prints it to the console |
# | | | |
# | | | |
# | '<font color="blue"> **type()** </font>' |  | When you pass an <font color="magenta"> **object** </font> as an <font color="red"> **argument** </font> to '<font color="blue"> **type()** </font>', it RETURNS the **type** (string, integer, float, boolean) of that <font color="Magenta"> **object** </font> |
# | | | |
# | | | |
# | '<font color="blue"> **len()** </font>' |  | When you pass an <font color="magenta"> **object** </font> as an <font color="red"> **argument** </font> to '<font color="blue"> **len()** </font>', it RETURNS the **length** of that <font color="Magenta"> **object** </font> |
# | | | ONLY Usable on: Strings, Lists, Tuples, Dictionaries, Sets, or Arrays |
# | | | |
# | | | |
# | '<font color="blue"> **min()** </font>' |  | Takes input like an **iterable** (= list or tuple) or **two or more <font color="lightseagreen"> parameters </font>** AND RETURNS the **SMALLEST item** within that input |
# | | | |
# | | | |
# | '<font color="blue"> **max()** </font>' |  | Takes input like an **iterable** (= list or tuple) or **two or more <font color="lightseagreen"> parameters </font>** AND RETURNS the **LARGEST item** within that input |
# | | | |
# | | | |
# | '<font color="blue"> **sum()** </font>' |  | Takes input like an **iterable** (= list or tuple) or **two or more <font color="lightseagreen"> parameters </font>** AND RETURNS the **SUM** of all the inputs |
# | | | adds up all the items in the input |
# | | | |
# | | | |
#
#
# ------------------------------------------------------------

# %% [markdown]
# ## **Method**
# -------------------------------------------------------------------
#
# #### **<u> Definition </u>**:
# = a piece of <font color="steelblue"> **code** </font> that performs a specific task and is associated with an <font color="magenta"> **object** </font>.
#
# >
# >
#
# - Similar to a <font color="blue"> **function** </font> but it is associated with an <font color="magenta"> **object** </font> and is called on that <font color="magenta"> **object** </font>
#
# >
# >
#
# - It is defined within a **class** and is meant to be used on instances of that **class**
#
# #### **<u> Action </u>**:
# - Its a type of <font color="blue"> **function** </font> that is associated with an <font color="magenta"> **object** </font> and when called upon you are calling a **method** of the <font color="magenta"> **object** </font> to perform a specific **operation**
# - Can access and modify the **data** of the <font color="magenta"> **object** </font> it belongs to
# >
# >
#
# #### **<u> Markdown Color </u>**:
# - "RoyalBlue"
# - <font color="RoyalBlue"> **method** </font>
#
# >
# >
# #### **<u> Examples </u>**:
#
# - kkk
# - jjjj
# >
# >
#
# |     |     | Definition |
# | --- | --- | ---------- |
# | '<font color="RoyalBlue"> **.remove()** </font>' |  | ?? |
# | | | |
# | | | |
# | '<font color="RoyalBlue"> **.append()** </font>' |  | Used on a specific **list** to **add an item** to that **list** |
# | | | Used on **list** <font color="magenta"> **objects** </font> in Python |
# | | | |
# | | | |
#
# ------------------------------------------------------------

# %% [markdown]
# test
